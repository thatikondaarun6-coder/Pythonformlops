# %% [markdown]
# <a href="https://colab.research.google.com/github/thatikondaarun6-coder/Pythonformlops/blob/future%2Fchecking-and-changing-data-type-in-python/checkingdatatype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# checking data  type
x=20
y="arun"
z=12.4
A=2.333
b = {"item": "1", "quantity": "2"}

print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'dict'>
