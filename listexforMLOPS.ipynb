# %% [markdown]
# <a href="https://colab.research.google.com/github/thatikondaarun6-coder/Pythonformlops/blob/Data_structures/listexforMLOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import mod
# dictinoary

model_config = {
    "model_name": "LogisticRegression",
    "version": "1.0",
    "accuracy": 0.92,
    "f1_score": 0.89,
    "status": "deployed",
     "model_name": "LogisticRegression",
    "version": "1.0",
    "accuracy": 0.91,
    "f1_score": 0.89,
    "status": "deployed"
}

print("keys:",model_config['accuracy'])
print("values:",model_config.values())
for i in model_config:
     print
# Out:
# keys: 0.91
# values: dict_values(['LogisticRegression', '1.0', 0.91, 0.89, 'deployed'])

# %%
# all key values

model_config = {
    "model_name": "LogisticRegression",
    "version": "1.0",
    "accuracy": 0.92,
    "f1_score": 0.89,
    "status": "deployed",
     "model_name": "LogisticRegression1",
    "version": "1.1",
    "accuracy": 0.34,
    "f1_score": 0.87,
    "status": "deployed"
}


print("\nMethod 2: Using keys() and values()")
for key in model_config.keys():
    print(f"{key}: {model_config[key]}")
# Out:
# Method 2: Using keys() and values()
# model_name: LogisticRegression1
# version: 1.1
# accuracy: 0.34
# f1_score: 0.87
# status: deployed
