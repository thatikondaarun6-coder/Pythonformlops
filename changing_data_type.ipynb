# %% [markdown]
# <a href="https://colab.research.google.com/github/thatikondaarun6-coder/Pythonformlops/blob/future%2Fchecking-and-changing-data-type-in-python/changing_data_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#changing Data types
#convert to string  to int d types
x="101"
y=int(x)
print(y)
# Out:
# 101

# %%
#convert to string to other float types
x="101"
y=float(x)
print(y)
# Out:
# 101.0

# %%
from decimal import Decimal

#convert to string to other decimal types
x="101"
y=Decimal(x)
print(y)
# Out:
# 101

# %%
a="2"
b="3"

c=(float(a)+int(b))

print(f"a + b = {c}")
# Out:
# a + b = 5.0

# %%
import datetime
today = datetime.datetime.today()
print(f"Today is {today:%B %d, %Y}")
# Out:
# Today is May 11, 2026
