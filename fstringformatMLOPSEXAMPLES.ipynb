# %% [markdown]
# <a href="https://colab.research.google.com/github/thatikondaarun6-coder/Pythonformlops/blob/future%2Fchecking-and-changing-data-type-in-python/fstringformatMLOPSEXAMPLES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# f string format MLOPS EXAMPLES
#Logging ML Metrics
model_name = "RandomForest"
accuracy = 0.92345
loss = 0.123456

print(f"Model: {model_name:<15} | Accuracy: {accuracy:.2%} | Loss: {loss:.4f}")
# Out:
# Model: RandomForest    | Accuracy: 92.34% | Loss: 0.1235

# %%
# Airflow DAG Task Status
task = "Data Preprocessing"
status = "SUCCESS"
duration = 123.456

print(f"Task: {task:^20} | Status: {status:<10} | Duration: {duration:.2f}s")
# Out:
# Task:  Data Preprocessing  | Status: SUCCESS    | Duration: 123.46s

# %%
#Resource Monitoring in Docker
cpu_usage = 0.4523
memory_usage = 123456789

print(f"CPU: {cpu_usage:.1%} | Memory: {memory_usage/1024**2:,.2f} MB")
# Out:
# CPU: 45.2% | Memory: 117.74 MB

# %%
# Experiment Tracking (MLflow style)
experiment_id = 42
run_id = "abc123"
metric = 0.87654321

print(f"Experiment {experiment_id:04d} | Run {run_id} | Metric: {metric:.3f}")
# Out:
# Experiment 0042 | Run abc123 | Metric: 0.877

# %%
# Conditional Reporting
accuracy = 0.78
print(f"Model performance: {'Good' if accuracy > 0.8 else 'Needs Improvement'}")
# Out:
# Model performance: Needs Improvement

# %%
passing_score=int(input("enter number: "))
print(f" passpercentage : {'passed'if passing_score>=35 else'fail'}")
# Out:
# enter number: 30
#  passpercentage : fail
